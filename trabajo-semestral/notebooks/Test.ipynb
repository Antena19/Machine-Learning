# %%
# %load_ext kedro.ipython
# Out:
# [09/04/25 21:34:17] INFO     Using                                                                  ]8;id=191192;file://C:\Machine-Learning\Machine-Learning\trabajo-semestral\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=800420;file://C:\Machine-Learning\Machine-Learning\trabajo-semestral\.venv\Lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'C:\Machine-Learning\Machine-Learning\trabajo-semestral\.venv\Lib\site
#                              -packages\kedro\framework\project\rich_logging.yml' as logging
#                              configuration.
# ...

# %%
catalog.keys()
